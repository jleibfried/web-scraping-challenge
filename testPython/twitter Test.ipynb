# %%
import requests
import pymongo
from splinter import Browser
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url_jpl = 'https://twitter.com/marswxreport?lang=en'
browser.visit(url_jpl)
newHtml = browser.html
soup = BeautifulSoup(newHtml, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" style="font-size: 15px;" xmlns="http://www.w3.org/1999/xhtml"><head><meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
# <link href="//abs.twimg.com" rel="preconnect"/>
# <link href="//api.twitter.com" rel="preconnect"/>
# <link href="//pbs.twimg.com" rel="preconnect"/>
# <link href="//t.co" rel="preconnect"/>
# <link href="//video.twimg.com" rel="preconnect"/>
# <link href="//abs.twimg.com" rel="dns-prefetch"/>
# <link href="//api.twitter.com" rel="dns-prefetch"/>
# <link href="//pbs.twimg.com" rel="dns-prefetch"/>
# <link href="//t.co" rel="dns-prefetch"/>
# <link href="//video.twimg.com" rel="dns-prefetch"/>
# <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/web/polyfills.aa560c44.js" nonce="" rel="preload"/>
# ...

# %%
out = soup.find('div', class_='css-1dbjc4n')
outer = out.find('div', class_='css-1dbjc4n r-14lw9ot r-18u37iz r-1h3ijdo r-1wtj0ep r-utggzx r-rjfia r-136ojw6')
outer

# %%
outer = soup.find('div', class_='css-901oao r-hkyrab r-1qd0xha r-a023e6 r-16dba41 r-ad9z0x r-bcqeeo r-bnwqim r-qvutc0')

# %%
weather_url = "https://twitter.com/marswxreport?lang=en"
# weather_url = "https://twitter.com/MarsWxReport/status/1271062426532839427"
try:
    browser.visit(weather_url)
except:
    # In case the browser gets closed after getting the jpl content
    executable_path = {'executable_path': 'chromedriver.exe'}
    browser = Browser('chrome', **executable_path, headless=False)
    browser.visit(weather_url)
    
newHtml = browser.html
soup = BeautifulSoup(newHtml, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" style="font-size: 15px;" xmlns="http://www.w3.org/1999/xhtml"><head><meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
# <link href="//abs.twimg.com" rel="preconnect"/>
# <link href="//api.twitter.com" rel="preconnect"/>
# <link href="//pbs.twimg.com" rel="preconnect"/>
# <link href="//t.co" rel="preconnect"/>
# <link href="//video.twimg.com" rel="preconnect"/>
# <link href="//abs.twimg.com" rel="dns-prefetch"/>
# <link href="//api.twitter.com" rel="dns-prefetch"/>
# <link href="//pbs.twimg.com" rel="dns-prefetch"/>
# <link href="//t.co" rel="dns-prefetch"/>
# <link href="//video.twimg.com" rel="dns-prefetch"/>
# <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/web/polyfills.aa560c44.js" nonce="" rel="preload"/>
# ...

# %%
mars_weather = ""# Keep refreshing the browser HTML until the first Tweet update loads
while (mars_weather == ""):
    # Recreate the HTML and Soup
    weather_html = browser.html
    weather_soup = BeautifulSoup(weather_html, 'html.parser')
weather_soup

# %%
newHtml = browser.html
soup = BeautifulSoup(newHtml, 'html.parser')
soup

# %%
# abject failure
# url = 'https://twitter.com/MarsWxReport/status/1269129701097967616'

# # Retrieve page with the requests module
# response = requests.get(url)
# # Create BeautifulSoup object; parse with 'html'
# soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
# <link href="//abs.twimg.com" rel="preconnect"/>
# <link href="//api.twitter.com" rel="preconnect"/>
# <link href="//pbs.twimg.com" rel="preconnect"/>
# <link href="//t.co" rel="preconnect"/>
# <link href="//video.twimg.com" rel="preconnect"/>
# <link href="//abs.twimg.com" rel="dns-prefetch"/>
# <link href="//api.twitter.com" rel="dns-prefetch"/>
# <link href="//pbs.twimg.com" rel="dns-prefetch"/>
# <link href="//t.co" rel="dns-prefetch"/>
# <link href="//video.twimg.com" rel="dns-prefetch"/>
# <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/web/polyfills.604422d4.js" nonce="ZjU2MzI2OTgtNzRhNS00MjEwLTg1YzAtM2RlODBiNDcyZDIx" rel="preload"/>
# ...

# %%
firstgrab = soup.find('div', id="react-root")
firstgrab
# Out:
# <div id="react-root" style="height:100%;display:flex;"><div class="css-1dbjc4n r-13awgt0 r-12vffkv"><div class="css-1dbjc4n r-13awgt0 r-12vffkv"><div aria-label="Loading…" class="css-1dbjc4n r-14lw9ot r-1p0dtai r-1d2f490 r-1xcajam r-zchlnj r-ipm5af"><svg class="r-1p0dtai r-13gxpu9 r-4qtqp9 r-yyyyoo r-wy61xf r-1d2f490 r-ywje51 r-dnmrzs r-u8s1d r-zchlnj r-1plcrui r-ipm5af r-lrvibr r-1blnp2b" viewbox="0 0 24 24"><g><path d="M23.643 4.937c-.835.37-1.732.62-2.675.733.962-.576 1.7-1.49 2.048-2.578-.9.534-1.897.922-2.958 1.13-.85-.904-2.06-1.47-3.4-1.47-2.572 0-4.658 2.086-4.658 4.66 0 .364.042.718.12 1.06-3.873-.195-7.304-2.05-9.602-4.868-.4.69-.63 1.49-.63 2.342 0 1.616.823 3.043 2.072 3.878-.764-.025-1.482-.234-2.11-.583v.06c0 2.257 1.605 4.14 3.737 4.568-.392.106-.803.162-1.227.162-.3 0-.593-.028-.877-.082.593 1.85 2.313 3.198 4.352 3.234-1.595 1.25-3.604 1.995-5.786 1.995-.376 0-.747-.022-1.112-.065 2.062 1.323 4.51 2.093 7.14 2.093 8.57 0 13.255-7.098 13.255-13.254 0-.2-.005-.402-.014
# ...

# %%
firstgrab.find('div', class_=)
# Out:
# <div class="css-1dbjc4n r-13awgt0 r-12vffkv"><div class="css-1dbjc4n r-13awgt0 r-12vffkv"><div aria-label="Loading…" class="css-1dbjc4n r-14lw9ot r-1p0dtai r-1d2f490 r-1xcajam r-zchlnj r-ipm5af"><svg class="r-1p0dtai r-13gxpu9 r-4qtqp9 r-yyyyoo r-wy61xf r-1d2f490 r-ywje51 r-dnmrzs r-u8s1d r-zchlnj r-1plcrui r-ipm5af r-lrvibr r-1blnp2b" viewbox="0 0 24 24"><g><path d="M23.643 4.937c-.835.37-1.732.62-2.675.733.962-.576 1.7-1.49 2.048-2.578-.9.534-1.897.922-2.958 1.13-.85-.904-2.06-1.47-3.4-1.47-2.572 0-4.658 2.086-4.658 4.66 0 .364.042.718.12 1.06-3.873-.195-7.304-2.05-9.602-4.868-.4.69-.63 1.49-.63 2.342 0 1.616.823 3.043 2.072 3.878-.764-.025-1.482-.234-2.11-.583v.06c0 2.257 1.605 4.14 3.737 4.568-.392.106-.803.162-1.227.162-.3 0-.593-.028-.877-.082.593 1.85 2.313 3.198 4.352 3.234-1.595 1.25-3.604 1.995-5.786 1.995-.376 0-.747-.022-1.112-.065 2.062 1.323 4.51 2.093 7.14 2.093 8.57 0 13.255-7.098 13.255-13.254 0-.2-.005-.402-.014-.602.91-.658 1.7-1.477 2.323-2.41z"></path></g></svg><
# ...

# %%
firstTitle = soup.find('span' class_='css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0').text
firstTitle
# Out:
#   File "<ipython-input-30-f9cefdc7b882>", line 1
#     firstTitle = soup.find('span' class_='css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0').text
#                                        ^
# SyntaxError: invalid syntax

# %%
data = requests.get(url)
print(data.text)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <meta charset="utf-8" />
# <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" />
# <link rel="preconnect" href="//abs.twimg.com" />
# <link rel="preconnect" href="//api.twitter.com" />
# <link rel="preconnect" href="//pbs.twimg.com" />
# <link rel="preconnect" href="//t.co" />
# <link rel="preconnect" href="//video.twimg.com" />
# <link rel="dns-prefetch" href="//abs.twimg.com" />
# <link rel="dns-prefetch" href="//api.twitter.com" />
# <link rel="dns-prefetch" href="//pbs.twimg.com" />
# <link rel="dns-prefetch" href="//t.co" />
# <link rel="dns-prefetch" href="//video.twimg.com" />
# <link rel="preload" as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/web/polyfills.604422d4.js" nonce="YmNjYmI2NTItZjgwMi00YjIwLTk5OTYtOTRhM2NjNjM0MWMy" />
# ...

# %%
all_tweets = []

html = BeautifulSoup(data.text, 'html.parser')
timeline = html.select('#timeline li.stream-item')

for tweet in timeline:

    tweet_id = tweet['data-item-id']
    tweet_text = tweet.select('p.tweet-text')[0].get_text()

    all_tweets.append({"id": tweet_id, "text": tweet_text})

# %%
# Out:
# []

# %%
html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

# Gets the tweet
tweets = soup.span

# %%
tweets
# Out:
# <span class="css-901oao css-16my406" dir="auto">Something went wrong, but don’t fret — let’s give it another shot.</span>

# %%
url = 'https://twitter.com/marswxreport?lang=en'
html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
# <link href="//abs.twimg.com" rel="preconnect"/>
# <link href="//api.twitter.com" rel="preconnect"/>
# <link href="//pbs.twimg.com" rel="preconnect"/>
# <link href="//t.co" rel="preconnect"/>
# <link href="//video.twimg.com" rel="preconnect"/>
# <link href="//abs.twimg.com" rel="dns-prefetch"/>
# <link href="//api.twitter.com" rel="dns-prefetch"/>
# <link href="//pbs.twimg.com" rel="dns-prefetch"/>
# <link href="//t.co" rel="dns-prefetch"/>
# <link href="//video.twimg.com" rel="dns-prefetch"/>
# <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/web/polyfills.604422d4.js" nonce="M2MzZGVkM2QtYjMxYy00MjA2LWFmY2EtZDlkODJlM2VhNWMx" rel="preload"/>
# ...

# %%
tables = pd.read_html(url)
tables
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-03630a51bf39> in <module>
# ----> 1 tables = pd.read_html(url)
#       2 tables
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     889     retained = None
#     890     for flav in flavor:
# --> 891         parser = _parser_dispatch(flav)
#     892         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     893
#
# ...

# %%
weather_url = "https://twitter.com/marswxreport?lang=en"

try:
    browser.visit(weather_url)
except:
    # In case the browser gets closed after getting the jpl content
    executable_path = {'executable_path': 'chromedriver.exe'}
    browser = Browser('chrome', **executable_path, headless=False)
    browser.visit(weather_url)

# %%
mars_weather = ""# Keep refreshing the browser HTML until the first Tweet update loads
while (mars_weather == ""):
    # Recreate the HTML and Soup
    weather_html = browser.html
    weather_soup = BeautifulSoup(weather_html, 'html.parser')
    
print(weather_soup.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-fcdc3a382e6d> in <module>
#       2 while (mars_weather == ""):
#       3     # Recreate the HTML and Soup
# ----> 4     weather_html = browser.html
#       5     weather_soup = BeautifulSoup(weather_html, 'html.parser')
#       6
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in html(self)
#     309     @property
#     310     def html(self):
# --> 311         return self.driver.page_source
#     312
#     313     @property
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ...

# %%
weather_soup.text
